# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
print ("Numpy v{}".format(np.__version__))
print ("Pandas v{}".format(pd.__version__))
print ("Seaborn v{}".format(sns.__version__))
# Out:
# Numpy v1.9.2
# Pandas v0.16.2
# Seaborn v0.6.0

# %%
#Abrimos los ficheros con los datos de las pruebas
#Tolva pequeña
data_p1 = pd.read_csv('prueba1.CSV')
#Tolva Graned
data_p2 = pd.read_csv('prueba2.CSV')

# %%
#El ensayo se realizo a distintas velocidades, se filtran los datos por
#velocidad rápida= v1 = 4.42mm/s
#velocidad lenta= v2 = 3.816mm/s
#Filtramos los datos con velocidad de tracción rápida
data_p1_v1 = data_p1[(data_p1['RPM TRAC'] >= 4) & (data_p1['RPM TRAC'] <= 4.42)]
data_p2_v1 = data_p2[(data_p2['RPM TRAC'] >= 4) & (data_p2['RPM TRAC'] <= 4.42)]
#Filtramos los datos con velocidad de tracción lenta
data_p1_v2 = data_p1[(data_p1['RPM TRAC'] > 0) & (data_p1['RPM TRAC'] <= 3.816)]
data_p2_v2 = data_p2[(data_p2['RPM TRAC'] > 0) & (data_p2['RPM TRAC'] <= 3.816)]

# %%
data_p1_v2.describe()
# Out:
#        Tmp Husillo   Tmp Nozzle   Diametro X   Diametro Y MARCHA  PARO  \
# count  1976.000000  1976.000000  1976.000000  1976.000000   1976  1976
# mean     64.848330   138.280719     1.463441     1.439575      1     1
# std       1.943604     0.707485     0.162796     0.177366      0     0
# min      59.800000   136.500000     0.010000     0.000000   True  True
# 25%      63.400000   137.800000     1.380000     1.350000      1     1
# 50%      65.100000   138.300000     1.460000     1.440000      1     1
# 75%      66.600000   138.700000     1.550000     1.540000      1     1
# max      67.700000   140.100000     2.400000     2.150000   True  True
#
#           RPM EXTR      RPM TRAC
# count  1976.000000  1.976000e+03
# mean      1.989372  3.814816e+00
# std       0.102567  4.291870e-08
# min       1.000000  3.814816e+00
# 25%       2.000000  3.814816e+00
# 50%       2.000000  3.814816e+00
# 75%       2.000000  3.814816e+00
# max       2.000000  3.814816e+00

# %%
columns = ['Tmp Husillo', 'Tmp Nozzle', 'Diametro X', 'Diametro Y', 'VELOCIDAD']
#columns = ['Tmp Husillo', 'Tmp Nozzle', 'Diametro X', 'Diametro Y', 'RPM TRAC']
data[columns].plot(subplots=True, figsize=(14,14))
# Out:
# array([<matplotlib.axes.AxesSubplot object at 0x109389990>,
# ...
#        <matplotlib.axes.AxesSubplot object at 0x1098379d0>], dtype=object)

# %%
data.ix[:, "Diametro X":"Diametro Y"].plot(figsize=(16,3))

# %%
data.ix[:, "Diametro X":"Diametro Y"].boxplot()
# Out:
# /Users/vgonpa/Library/Python/2.7/lib/python/site-packages/pandas/tools/plotting.py:2380: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   warnings.warn(msg, FutureWarning)
# {'boxes': [<matplotlib.lines.Line2D at 0x10aef0f10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x10aef0510>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x10aefb950>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x10aefb450>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x10aee2d10>,
# ...
#   <matplotlib.lines.Line2D at 0x10af07810>]}

# %% [markdown]
# #  Rolling Means

# %%
X = data['Diametro X']
#pd.rolling_mean(data['Diametro Y'], 50).plot()
X_mean = pd.rolling_mean(X, 50)
X_std = pd.rolling_std(X, 50)
X_mean.plot(figsize(12,6))
X.plot(figsize(12,6), alpha=0.5)
plt.fill_between(X, y1=X_mean+X_std, y2=X_mean-X_std, alpha=0.5)

# %%
pd.rolling_mean(data[columns], 50).plot(subplots=True, figsize=(12,12))
# Out:
# array([<matplotlib.axes.AxesSubplot object at 0x109f69150>,
# ...
#        <matplotlib.axes.AxesSubplot object at 0x10b4dfe50>], dtype=object)

# %%
plt.scatter(x=data['Diametro X'], y=data['Diametro Y'], marker='.')

# %% [markdown]
# # Filtering Data with diameter >= 0.5

# %% [markdown]
# I'm not sure if data with diameter $d_x >= 0.5$ or $d_y >= 0.5$ is an error. Hence, I'm filtering them.

# %%
data_filtered = data[(data['Diametro X'] >= 0.5) & (data['Diametro Y'] >= 0.5)]

# %% [markdown]
# ## Plotting X/Y ratio

# %% [markdown]
# Let's plot a $d_x$ vs $d_y$ scatterplot first

# %%
plt.scatter(x=data_filtered['Diametro X'], y=data_filtered['Diametro Y'], marker='.')

# %% [markdown]
# Getting $X/Y$ Ratio

# %%
ratio = data_filtered['Diametro X']/data_filtered['Diametro Y']

# %%
ratio.describe()
# Out:
# count    1387.000000
# mean        1.017628
# std         0.128013
# min         0.547176
# 25%         0.954444
# 50%         0.999451
# 75%         1.064433
# max         2.533221
# dtype: float64

# %%
rolling_mean = pd.rolling_mean(ratio, 50)
rolling_std = pd.rolling_std(ratio, 50)
rolling_mean.plot(figsize(12,6))
# plt.fill_between(ratio, y1=rolling_mean+rolling_std, y2=rolling_mean-rolling_std, alpha=0.5)
ratio.plot(figsize=(12,6), alpha=0.6, ylim=(0,3))

# %% [markdown]
# Histrogram of the ratio

# %%
ratio.hist(bins=50)

# %%
data_filtered[columns].corr()
# Out:
#              Tmp Husillo  Tmp Nozzle  Diametro X  Diametro Y  VELOCIDAD
# Tmp Husillo     1.000000    0.216891    0.245555    0.336489   0.394231
# Tmp Nozzle      0.216891    1.000000    0.170572    0.148273   0.240967
# Diametro X      0.245555    0.170572    1.000000    0.679199   0.252167
# Diametro Y      0.336489    0.148273    0.679199    1.000000   0.244315
# VELOCIDAD       0.394231    0.240967    0.252167    0.244315   1.000000

# %% [raw]
# rolling_std

# %% [markdown]
# # Calulating Limit Violations

# %% [markdown]
# Here we will check wether the diameter of the filament passes certain queality thresholds.
# $Th^+ = 1.85$ and $Th^- = 1.65$

# %%
Th_u = 1.85
Th_d = 1.65

# %%
data_violations = data[(data['Diametro X'] > Th_u) | (data['Diametro X'] < Th_d) |
                       (data['Diametro Y'] > Th_u) | (data['Diametro Y'] < Th_d)]

# %%
data_violations.describe()
# Out:
#        Tmp Husillo   Tmp Nozzle   Diametro X   Diametro Y MARCHA       PARO  \
# count  1271.000000  1271.000000  1271.000000  1271.000000   1271       1271
# mean     63.406137   134.549017     1.573344     1.524330      1  0.2171518
# std       1.073185     1.541764     0.625175     0.651855      0  0.4124691
# min      61.500000   129.400000     0.014000     0.000342   True      False
# 25%      62.500000   134.100000     1.505085     1.494436      1          0
# 50%      63.500000   134.700000     1.780362     1.747282      1          0
# 75%      64.100000   135.400000     1.975350     1.942664      1          0
# max      66.600000   139.000000     2.491494     2.310441   True       True
#
#          VELOCIDAD
# count  1271.000000
# mean      1.114752
# std       0.486605
# min       0.000000
# 25%       0.750000
# 50%       0.750000
# 75%       1.500000
# max       2.500000

# %%
data_violations.plot(subplots=True, figsize=(12,12))
# Out:
# array([<matplotlib.axes.AxesSubplot object at 0x10bdbbb10>,
# ...
#        <matplotlib.axes.AxesSubplot object at 0x10c79a510>], dtype=object)
